# %% [markdown]
# <a href="https://colab.research.google.com/github/007Anmol/Event-Feedback/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
import pandas as pd
import matplotlib.pyplot as plt
import random

# Set your Gemini API key
genai.configure(api_key='AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE')

# Verify available models
print("Available Models:")
for model in genai.list_models():
    print(model.name)

# Initialize the GenerativeModel with the correct model name
# Use 'gemini-1.0-pro' or 'gemini-1.5-pro' if 'gemini-pro' is not available
model = genai.GenerativeModel('gemini-1.0-pro')  # Use the correct model name

# Function to fetch event feedback using Gemini API
def fetch_event_feedback(event_name):
    prompt = f"Generate realistic reviews for the event '{event_name}' in India. Include positive, neutral, and negative feedback."
    response = model.generate_content(prompt)
    reviews = response.text.split('\n')
    return reviews

# Function to analyze sentiment using Gemini API
def analyze_sentiment(review):
    prompt = f"Classify the sentiment of the following review as 'Positive', 'Neutral', or 'Negative':\n\n{review}"
    response = model.generate_content(prompt)
    sentiment = response.text.strip()
    return sentiment

# Function to categorize feedback
def categorize_feedback(review):
    prompt = f"Categorize the following review into one of these categories: 'Event Organization', 'Content Quality', 'Venue & Facilities', 'Staff & Service', 'Value for Money':\n\n{review}"
    response = model.generate_content(prompt)
    category = response.text.strip()
    return category

# Function to analyze event feedback
def analyze_event_feedback(event_name):
    # Fetch reviews for the event
    reviews = fetch_event_feedback(event_name)

    # Initialize counters
    sentiment_counts = {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    category_counts = {
        'Event Organization': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Content Quality': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Venue & Facilities': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Staff & Service': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Value for Money': {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    }

    # Analyze each review
    for review in reviews:
        sentiment = analyze_sentiment(review)
        category = categorize_feedback(review)

        # Update sentiment counts
        sentiment_counts[sentiment] += 1

        # Update category counts
        if category in category_counts:
            category_counts[category][sentiment] += 1

    # Calculate sentiment percentages
    total_reviews = len(reviews)
    positive_percentage = (sentiment_counts['Positive'] / total_reviews) * 100
    neutral_percentage = (sentiment_counts['Neutral'] / total_reviews) * 100
    negative_percentage = (sentiment_counts['Negative'] / total_reviews) * 100

    print(f"\nSentiment Analysis for '{event_name}':")
    print(f"Positive: {positive_percentage:.2f}%")
    print(f"Neutral: {neutral_percentage:.2f}%")
    print(f"Negative: {negative_percentage:.2f}%")

    # Calculate category-wise feedback percentages
    print("\nCategory-wise Feedback:")
    for category, counts in category_counts.items():
        total = sum(counts.values())
        if total > 0:
            positive = (counts['Positive'] / total) * 100
            neutral = (counts['Neutral'] / total) * 100
            negative = (counts['Negative'] / total) * 100
            print(f"{category}: Positive={positive:.2f}%, Neutral={neutral:.2f}%, Negative={negative:.2f}%")

    # Simulate sentiment trends over the years
    years = list(range(2019, 2024))
    sentiment_trends = {year: {'Positive': 0, 'Neutral': 0, 'Negative': 0} for year in years}
    for review in reviews:
        sentiment = analyze_sentiment(review)
        year = random.choice(years)
        sentiment_trends[year][sentiment] += 1

    # Plot sentiment trends
    df_trends = pd.DataFrame(sentiment_trends).T
    df_trends.plot(kind='line', marker='o')
    plt.title(f'Sentiment Trends for {event_name} Over the Years')
    plt.xlabel('Year')
    plt.ylabel('Number of Reviews')
    plt.show()

# Take event name as input
event_name = input("Enter the event name: ")
analyze_event_feedback(event_name)
# Out:
# Available Models:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# ...

# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
from faker import Faker

# Initialize Faker for generating fake data
fake = Faker()

# Define sample data
event_names = [
    'Coldplay Concert Mumbai', 'Coldplay Concert Delhi', 'Coldplay Concert Bangalore',
    'Arijit Singh Live Mumbai', 'Arijit Singh Live Delhi', 'Arijit Singh Live Kolkata',
    'Sunburn Goa', 'Sunburn Mumbai', 'Sunburn Bangalore',
    'IPL Final Mumbai', 'IPL Final Delhi', 'IPL Final Bangalore',
    'Zakir Khan Standup Mumbai', 'Zakir Khan Standup Delhi', 'Zakir Khan Standup Pune',
    'Vir Das Comedy Show Mumbai', 'Vir Das Comedy Show Delhi', 'Vir Das Comedy Show Hyderabad',
    'NH7 Weekender Pune', 'NH7 Weekender Bangalore', 'NH7 Weekender Kolkata',
    'Lollapalooza Mumbai', 'Lollapalooza Delhi', 'Lollapalooza Bangalore',
    'Pro Kabaddi Final Mumbai', 'Pro Kabaddi Final Delhi', 'Pro Kabaddi Final Hyderabad',
    'Fashion Week Mumbai', 'Fashion Week Delhi', 'Fashion Week Bangalore',
    'Shreya Ghoshal Live Mumbai', 'Shreya Ghoshal Live Delhi', 'Shreya Ghoshal Live Chennai',
    'Ritviz x Nucleya Concert Mumbai', 'Ritviz x Nucleya Concert Delhi', 'Ritviz x Nucleya Concert Bangalore',
    'Trevor Noah India Tour Mumbai', 'Trevor Noah India Tour Delhi', 'Trevor Noah India Tour Bangalore',
    'Royal Enfield Rider Mania Goa', 'Royal Enfield Rider Mania Bangalore', 'Royal Enfield Rider Mania Chennai',
    'Comic Con Mumbai', 'Comic Con Delhi', 'Comic Con Bangalore',
    'Indian Super League Final Mumbai', 'Indian Super League Final Delhi', 'Indian Super League Final Kolkata',
    'Prateek Kuhad Live Mumbai', 'Prateek Kuhad Live Delhi', 'Prateek Kuhad Live Pune',
    'Badshah Concert Mumbai', 'Badshah Concert Delhi', 'Badshah Concert Bangalore',
    'Neha Kakkar Live Mumbai', 'Neha Kakkar Live Delhi', 'Neha Kakkar Live Kolkata',
    'Yo Yo Honey Singh Comeback Show Mumbai', 'Yo Yo Honey Singh Comeback Show Delhi', 'Yo Yo Honey Singh Comeback Show Bangalore',
    'Bhuvan Bam Live Mumbai', 'Bhuvan Bam Live Delhi', 'Bhuvan Bam Live Pune',
    'Rahul Subramanian Standup Mumbai', 'Rahul Subramanian Standup Delhi', 'Rahul Subramanian Standup Bangalore',
    'Amit Tandon Standup Mumbai', 'Amit Tandon Standup Delhi', 'Amit Tandon Standup Pune',
    'Gaurav Kapoor Standup Mumbai', 'Gaurav Kapoor Standup Delhi', 'Gaurav Kapoor Standup Bangalore',
    'Biswa Kalyan Rath Standup Mumbai', 'Biswa Kalyan Rath Standup Delhi', 'Biswa Kalyan Rath Standup Bangalore',
    'Indian Fashion Carnival Mumbai', 'Indian Fashion Carnival Delhi', 'Indian Fashion Carnival Bangalore',
    'Classical Night with Pandit Jasraj Mumbai', 'Classical Night with Pandit Jasraj Delhi', 'Classical Night with Pandit Jasraj Kolkata',
    'Theatre: Mughal-e-Azam Mumbai', 'Theatre: Mughal-e-Azam Delhi', 'Theatre: Mughal-e-Azam Bangalore',
    'Gully Boy Music Fest Mumbai', 'Gully Boy Music Fest Delhi', 'Gully Boy Music Fest Bangalore',
    'Nucleya Bass Rani Tour Mumbai', 'Nucleya Bass Rani Tour Delhi', 'Nucleya Bass Rani Tour Bangalore',
    'Samay Raina Live Mumbai', 'Samay Raina Live Delhi', 'Samay Raina Live Bangalore',
    'Rohan Joshi Standup Mumbai', 'Rohan Joshi Standup Delhi', 'Rohan Joshi Standup Bangalore',
    'Armaan Malik Live Mumbai', 'Armaan Malik Live Delhi', 'Armaan Malik Live Kolkata',
    'Sonu Nigam Live Mumbai', 'Sonu Nigam Live Delhi', 'Sonu Nigam Live Bangalore',
    'Divine x Ritviz Fusion Concert Mumbai', 'Divine x Ritviz Fusion Concert Delhi', 'Divine x Ritviz Fusion Concert Bangalore',
    'FIFA U17 Finals Kolkata', 'FIFA U17 Finals Delhi', 'FIFA U17 Finals Mumbai',
    'India Design Week Mumbai', 'India Design Week Delhi', 'India Design Week Bangalore',
    'Pro Wrestling League Mumbai', 'Pro Wrestling League Delhi', 'Pro Wrestling League Bangalore',
    'Virat Kohli Charity Match Mumbai', 'Virat Kohli Charity Match Delhi', 'Virat Kohli Charity Match Bangalore'
]

genres = ['Music', 'Comedy', 'Theatre', 'Sports', 'Fashion']
locations = ['Mumbai', 'Delhi', 'Bangalore', 'Hyderabad', 'Chennai', 'Pune', 'Kolkata', 'Ahmedabad', 'Goa', 'Jaipur']
categories = ['Content Quality', 'Venue & Facilities', 'Staff & Service', 'Value for Money']
sentiments = ['Positive', 'Neutral', 'Negative']

# Predefined reviews based on sentiment
positive_reviews = [
    'Amazing performance and great energy!', 'Loved the experience, highly recommended!',
    'Stellar show, exceeded expectations!', 'Fantastic vibe and great organization!',
    'Absolutely magical experience!', 'The event was well-organized and enjoyable.',
    'Great value for money, would attend again!', 'The artists were phenomenal!',
    'The venue was perfect and the staff was very helpful.', 'A night to remember!'
]

neutral_reviews = [
    'It was decent but nothing extraordinary.', 'Average event, could be better.',
    'Had fun but a few things could be improved.', 'Okayish experience overall.',
    'Mixed feelings, some good moments.', 'The event was alright, but not exceptional.',
    'Could have been better organized.', 'The performances were good, but the venue was cramped.',
    'Decent experience, but not worth the hype.', 'It was okay, but I expected more.'
]

negative_reviews = [
    'Disappointed with the organization.', 'Poor sound quality and bad management.',
    'Not worth the money spent.', 'Crowd management was terrible.', 'Expected better performances.',
    'The event was a complete letdown.', 'The staff was rude and unhelpful.',
    'The venue was too crowded and uncomfortable.', 'The performances were underwhelming.',
    'I would not recommend this event to anyone.'
]

# Generate the dataset
dataset = []
for event in event_names:
    for category in categories:
        # Generate 5 reviews per category for each event
        for _ in range(5):
            # Assign a random sentiment (ensure all sentiments are included)
            sentiment = random.choices(sentiments, weights=[0.6, 0.3, 0.1])[0]  # 60% Positive, 30% Neutral, 10% Negative

            if sentiment == 'Positive':
                review = random.choice(positive_reviews)
            elif sentiment == 'Neutral':
                review = random.choice(neutral_reviews)
            else:
                review = random.choice(negative_reviews)

            dataset.append({
                'event_name': event,
                'genre': random.choice(genres),
                'location': random.choice(locations),
                'review': review,
                'category': category,
                'sentiment': sentiment,
                'year': random.randint(2019, 2023)
            })

# Create DataFrame
df = pd.DataFrame(dataset)

# Save to CSV
csv_filename = 'realistic_event_feedback_dataset.csv'
df.to_csv(csv_filename, index=False)

print(f"Dataset created and saved as {csv_filename}")

# Function to analyze feedback for a specific event
def analyze_event_feedback(event_name):
    # Validate if the event exists in the dataset
    if event_name not in df['event_name'].unique():
        print(f"Event '{event_name}' not found in the dataset.")
        return

    # Filter data for the specific event
    event_data = df[df['event_name'] == event_name]

    # Calculate sentiment percentages
    sentiment_counts = event_data['sentiment'].value_counts(normalize=True) * 100
    print(f"\nSentiment Analysis for '{event_name}':")
    print(sentiment_counts)

    # Calculate category-wise feedback percentages
    category_feedback = event_data.groupby('category')['sentiment'].value_counts(normalize=True).unstack(fill_value=0) * 100
    print("\nCategory-wise Feedback:")
    print(category_feedback)

    # Plot sentiment trends over the years
    sentiment_trends = event_data.groupby(['year', 'sentiment']).size().unstack(fill_value=0)
    sentiment_trends.plot(kind='line', marker='o')
    plt.title(f'Sentiment Trends for {event_name} Over the Years')
    plt.xlabel('Year')
    plt.ylabel('Number of Reviews')
    plt.show()

# Display available events
available_events = df['event_name'].unique()
print("Available Events:")
for i, event in enumerate(available_events, 1):
    print(f"{i}. {event}")

# Take event name as input
while True:
    try:
        event_choice = int(input("\nEnter the number corresponding to the event you want to analyze: "))
        if 1 <= event_choice <= len(available_events):
            event_name = available_events[event_choice - 1]
            break
        else:
            print("Invalid choice. Please enter a number from the list.")
    except ValueError:
        print("Invalid input. Please enter a number.")

# Analyze the selected event
analyze_event_feedback(event_name)
# Out:
# Dataset created and saved as realistic_event_feedback_dataset.csv
# Available Events:
# 1. Coldplay Concert Mumbai
# 2. Coldplay Concert Delhi
# 3. Coldplay Concert Bangalore
# 4. Arijit Singh Live Mumbai
# 5. Arijit Singh Live Delhi
# 6. Arijit Singh Live Kolkata
# 7. Sunburn Goa
# 8. Sunburn Mumbai
# 9. Sunburn Bangalore
# 10. IPL Final Mumbai
# 11. IPL Final Delhi
# 12. IPL Final Bangalore
# 13. Zakir Khan Standup Mumbai
# 14. Zakir Khan Standup Delhi
# 15. Zakir Khan Standup Pune
# 16. Vir Das Comedy Show Mumbai
# 17. Vir Das Comedy Show Delhi
# 18. Vir Das Comedy Show Hyderabad
# 19. NH7 Weekender Pune
# 20. NH7 Weekender Bangalore
# 21. NH7 Weekender Kolkata
# 22. Lollapalooza Mumbai
# 23. Lollapalooza Delhi
# 24. Lollapalooza Bangalore
# 25. Pro Kabaddi Final Mumbai
# 26. Pro Kabaddi Final Delhi
# 27. Pro Kabaddi Final Hyderabad
# 28. Fashion Week Mumbai
# 29. Fashion Week Delhi
# 30. Fashion Week Bangalore
# 31. Shreya Ghoshal Live Mumbai
# 32. Shreya Ghoshal Live Delhi
# ...

# %%
import google.generativeai as genai
import pandas as pd
import matplotlib.pyplot as plt
import random
import json

# Configure Gemini API Key
genai.configure(api_key='AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE')

# Verify available models
print("Available Models:")
for model in genai.list_models():
    print(model.name)

# Initialize the GenerativeModel
model = genai.GenerativeModel('gemini-1.5-pro')

# Function to fetch event feedback using Gemini API
def fetch_event_feedback(event_name):
    prompt = f"""
    Generate 10 realistic and detailed reviews for the event '{event_name}' in India.
    The reviews should cover different aspects such as the quality of performances, venue facilities, staff behavior, and value for money.
    Include a balanced mix of positive, neutral, and negative feedback.
    Each review should be at least 2-3 sentences long and provide specific details.

    Return the reviews in JSON array format like:
    {{
        "reviews": [
            "Review 1",
            "Review 2",
            ...
        ]
    }}
    """
    response = model.generate_content(prompt)

    try:
        reviews_json = json.loads(response.text.strip())
        reviews = reviews_json.get("reviews", [])
    except Exception as e:
        print("Error parsing reviews response:", e)
        reviews = []

    return reviews

# Function to analyze sentiment using Gemini API
def analyze_sentiment(review):
    prompt = f"""
    Analyze the sentiment of the following review and classify it strictly as 'Positive', 'Neutral', or 'Negative'.

    Return only a JSON object like this:
    {{
        "sentiment": "Positive"
    }}

    Review: {review}
    """
    response = model.generate_content(prompt)

    try:
        sentiment_json = json.loads(response.text.strip())
        sentiment = sentiment_json.get("sentiment", "Neutral")  # Default to Neutral if not found
    except Exception as e:
        print("Error parsing sentiment response:", e)
        sentiment = "Neutral"

    return sentiment

# Function to categorize feedback using Gemini API
def categorize_feedback(review):
    prompt = f"""
    Categorize the following review into one of these categories:
    'Event Organization', 'Content Quality', 'Venue & Facilities', 'Staff & Service', 'Value for Money'.

    Return only a JSON object like this:
    {{
        "category": "Content Quality"
    }}

    Review: {review}
    """
    response = model.generate_content(prompt)

    try:
        category_json = json.loads(response.text.strip())
        category = category_json.get("category", "Content Quality")  # Default fallback
    except Exception as e:
        print("Error parsing category response:", e)
        category = "Content Quality"

    return category

# Function to analyze event feedback
def analyze_event_feedback(event_name):
    print(f"\nAnalyzing feedback for event: {event_name}...\n")

    # Fetch reviews for the event
    reviews = fetch_event_feedback(event_name)

    if not reviews:
        print("No reviews generated. Exiting analysis.")
        return

    # Initialize counters
    sentiment_counts = {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    category_counts = {
        'Event Organization': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Content Quality': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Venue & Facilities': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Staff & Service': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Value for Money': {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    }

    # Cache results to avoid redundant processing
    review_analysis_results = []

    # Analyze each review
    for review in reviews:
        sentiment = analyze_sentiment(review)
        category = categorize_feedback(review)

        print(f"\nReview: {review}")
        print(f"-> Sentiment: {sentiment}")
        print(f"-> Category: {category}")

        # Cache the analysis
        review_analysis_results.append({'review': review, 'sentiment': sentiment, 'category': category})

        # Update counters
        sentiment_counts[sentiment] += 1
        if category in category_counts:
            category_counts[category][sentiment] += 1

    # Calculate sentiment percentages
    total_reviews = len(reviews)
    positive_percentage = (sentiment_counts['Positive'] / total_reviews) * 100
    neutral_percentage = (sentiment_counts['Neutral'] / total_reviews) * 100
    negative_percentage = (sentiment_counts['Negative'] / total_reviews) * 100

    print(f"\n📊 Sentiment Analysis for '{event_name}':")
    print(f"Positive: {positive_percentage:.2f}% ({sentiment_counts['Positive']})")
    print(f"Neutral: {neutral_percentage:.2f}% ({sentiment_counts['Neutral']})")
    print(f"Negative: {negative_percentage:.2f}% ({sentiment_counts['Negative']})")

    # Category-wise feedback summary
    print("\n📂 Category-wise Feedback Summary:")
    for category, counts in category_counts.items():
        total = sum(counts.values())
        if total > 0:
            pos = (counts['Positive'] / total) * 100
            neu = (counts['Neutral'] / total) * 100
            neg = (counts['Negative'] / total) * 100
            print(f"{category}: Positive={pos:.2f}%, Neutral={neu:.2f}%, Negative={neg:.2f}%")

    # Simulate sentiment trends over years
    years = list(range(2019, 2024))
    sentiment_trends = {year: {'Positive': 0, 'Neutral': 0, 'Negative': 0} for year in years}

    # Distribute reviews randomly across years
    for analysis in review_analysis_results:
        year = random.choice(years)
        sentiment = analysis['sentiment']
        sentiment_trends[year][sentiment] += 1

    # Plot sentiment trends
    df_trends = pd.DataFrame(sentiment_trends).T
    df_trends.plot(kind='line', marker='o')
    plt.title(f'Sentiment Trends for {event_name} Over the Years')
    plt.xlabel('Year')
    plt.ylabel('Number of Reviews')
    plt.grid(True)
    plt.show()

# Take event name as input from the user
event_name = input("Enter the event name: ")
analyze_event_feedback(event_name)
# Out:
# Available Models:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# ...

# %%
import google.generativeai as genai
import pandas as pd
import matplotlib.pyplot as plt
import random
import json
import time

# Configure Gemini with your API Key
genai.configure(api_key='AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE')

# Check available models
print("Available Models:")
for model in genai.list_models():
    print(model.name)

# Initialize the GenerativeModel with the best model name
# Recommended: models/gemini-2.0-pro-exp or models/gemini-1.5-pro
model_name = 'models/gemini-2.0-pro-exp'
model = genai.GenerativeModel(model_name)

# Function to fetch event feedback using Gemini API
def fetch_event_feedback(event_name, retries=3, delay=2):
    prompt = f"""
    Generate 10 realistic and detailed reviews for the event '{event_name}' in India.
    Each review should cover:
    - Quality of performances
    - Venue facilities
    - Staff behavior
    - Value for money

    Ensure a mix of Positive, Neutral, and Negative feedback.

    Return STRICTLY a JSON object in this format:
    {{
      "reviews": [
        "Review 1",
        "Review 2",
        ...
      ]
    }}

    Only return valid JSON. Do NOT include explanations or extra text.
    """

    for attempt in range(1, retries + 1):
        print(f"\nFetching reviews... Attempt {attempt}")
        try:
            response = model.generate_content(prompt)
            print("Raw response:")
            print(response.text)

            reviews_json = json.loads(response.text.strip())
            reviews = reviews_json.get("reviews", [])

            if not reviews:
                print("No reviews found in JSON.")
                continue

            return reviews

        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
            time.sleep(delay)
        except Exception as e:
            print(f"Unexpected error: {e}")
            time.sleep(delay)

    print("Failed to fetch reviews after retries.")
    return []

# Function to analyze sentiment using Gemini API
def analyze_sentiment(review):
    prompt = f"""
    Analyze the sentiment of this review and classify it as exactly one of these: Positive, Neutral, or Negative.

    Return STRICTLY the classification only. NO explanation.

    Review: "{review}"
    """
    try:
        response = model.generate_content(prompt)
        sentiment = response.text.strip()
        print(f"Sentiment for review: {sentiment}")
        if sentiment not in ['Positive', 'Neutral', 'Negative']:
            sentiment = 'Neutral'  # Fallback in case Gemini outputs weird text
        return sentiment
    except Exception as e:
        print(f"Error analyzing sentiment: {e}")
        return 'Neutral'

# Function to categorize feedback
def categorize_feedback(review):
    prompt = f"""
    Categorize this review into exactly one of these categories:
    - Event Organization
    - Content Quality
    - Venue & Facilities
    - Staff & Service
    - Value for Money

    Return STRICTLY the category only. NO explanation.

    Review: "{review}"
    """
    try:
        response = model.generate_content(prompt)
        category = response.text.strip()
        print(f"Category for review: {category}")
        categories = ['Event Organization', 'Content Quality', 'Venue & Facilities', 'Staff & Service', 'Value for Money']
        if category not in categories:
            category = 'Event Organization'  # Fallback
        return category
    except Exception as e:
        print(f"Error categorizing feedback: {e}")
        return 'Event Organization'

# Main analysis function
def analyze_event_feedback(event_name):
    print(f"\nAnalyzing feedback for event: {event_name}...")

    # Fetch reviews
    reviews = fetch_event_feedback(event_name)

    if not reviews:
        print("No reviews generated. Exiting analysis.")
        return

    # Initialize counters
    sentiment_counts = {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    category_counts = {
        'Event Organization': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Content Quality': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Venue & Facilities': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Staff & Service': {'Positive': 0, 'Neutral': 0, 'Negative': 0},
        'Value for Money': {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    }

    # Analyze each review
    for idx, review in enumerate(reviews, start=1):
        print(f"\nReview {idx}: {review}")
        sentiment = analyze_sentiment(review)
        category = categorize_feedback(review)

        # Update sentiment counts
        sentiment_counts[sentiment] += 1

        # Update category counts
        if category in category_counts:
            category_counts[category][sentiment] += 1

    # Total reviews
    total_reviews = len(reviews)

    # Sentiment percentages
    positive_percentage = (sentiment_counts['Positive'] / total_reviews) * 100
    neutral_percentage = (sentiment_counts['Neutral'] / total_reviews) * 100
    negative_percentage = (sentiment_counts['Negative'] / total_reviews) * 100

    print(f"\nSentiment Analysis for '{event_name}':")
    print(f"Positive: {positive_percentage:.2f}%")
    print(f"Neutral: {neutral_percentage:.2f}%")
    print(f"Negative: {negative_percentage:.2f}%")

    # Category-wise feedback percentages
    print("\nCategory-wise Feedback:")
    for category, counts in category_counts.items():
        total = sum(counts.values())
        if total > 0:
            positive = (counts['Positive'] / total) * 100
            neutral = (counts['Neutral'] / total) * 100
            negative = (counts['Negative'] / total) * 100
            print(f"{category}: Positive={positive:.2f}%, Neutral={neutral:.2f}%, Negative={negative:.2f}%")

    # Simulate sentiment trends over the years
    years = list(range(2019, 2024))
    sentiment_trends = {year: {'Positive': 0, 'Neutral': 0, 'Negative': 0} for year in years}

    for review in reviews:
        sentiment = analyze_sentiment(review)
        year = random.choice(years)
        sentiment_trends[year][sentiment] += 1

    # Plot sentiment trends
    df_trends = pd.DataFrame(sentiment_trends).T
    df_trends.plot(kind='line', marker='o')
    plt.title(f'Sentiment Trends for {event_name} Over the Years')
    plt.xlabel('Year')
    plt.ylabel('Number of Reviews')
    plt.grid(True)
    plt.legend(title='Sentiment')
    plt.show()

# --- MAIN ---
if __name__ == "__main__":
    event_name = input("Enter the event name: ")
    analyze_event_feedback(event_name)
# Out:
# Available Models:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# ...

# %%
import google.generativeai as genai
import json

# Configure Gemini Pro
genai.configure(api_key="AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE")  # Replace with your Gemini API Key

# Initialize Gemini Pro Model
model = genai.GenerativeModel("gemini-1.5-pro")

def fetch_event_feedback(event_name):
    """
    Fetches feedback insights for a given event using Gemini LLM.

    Parameters:
    - event_name (str): Name of the event to analyze.

    Returns:
    - dict: Structured feedback insights including positive/negative percentages,
            category breakdowns, and yearly sentiment trends.
    """

    # Detailed prompt sent to Gemini LLM
    prompt = f"""
You are an expert data analyst working for an event management company. You have full access to detailed feedback data collected over the years for the event "{event_name}".

Your job is to:
1. Analyze and summarize the feedback data.
2. Present the insights in a structured JSON format.
3. Make sure the data is consistent and realistic.

Here is what you need to include in the response:

1. **positive_feedback_percentage**: The percentage of all feedback that is classified as positive. Keep it realistic, between 50% and 100%.

2. **negative_feedback_percentage**: The percentage of all feedback that is classified as negative. This should add up with positive feedback to 100%.

3. **total_feedback_count**: A realistic total number of feedback entries considered. Assume the event is popular, so return a number between 500 and 10,000.

4. **categories**: Break down the feedback into the following categories, each with a percentage (out of 100%). Make sure the percentages reflect a well-balanced distribution:
   - Event Organization
   - Content Quality
   - Venue & Facilities
   - Staff & Service
   - Value for Money

5. **yearly_sentiment_trends**: Provide a list of objects, each representing a year. For each year, show:
   - year (last 5 years: from 2020 to 2024)
   - positive (number of positive feedback entries for that year)
   - negative (number of negative feedback entries for that year)
   Ensure that positive feedback generally increases over the years as the event improves, and negative feedback decreases.

### FORMAT:
Return the full response strictly in JSON format like this:

{{
  "positive_feedback_percentage": 85,
  "negative_feedback_percentage": 15,
  "total_feedback_count": 2500,
  "categories": {{
    "Event Organization": 80,
    "Content Quality": 85,
    "Venue & Facilities": 75,
    "Staff & Service": 78,
    "Value for Money": 82
  }},
  "yearly_sentiment_trends": [
    {{"year": 2020, "positive": 300, "negative": 100}},
    {{"year": 2021, "positive": 400, "negative": 90}},
    {{"year": 2022, "positive": 500, "negative": 80}},
    {{"year": 2023, "positive": 600, "negative": 70}},
    {{"year": 2024, "positive": 700, "negative": 50}}
  ]
}}

### Rules:
- Do not include explanations.
- Do not add extra text. Only return the JSON object.
- Ensure the numbers are consistent. Positive + Negative feedback per year should make sense.
"""

    # Generate content from Gemini
    response = model.generate_content(prompt)

    # Get the response text
    response_text = response.text.strip()

    # Optional: Print the raw response for debugging
    print("\n=== RAW RESPONSE ===\n")
    print(response_text)
    print("\n====================\n")

    # Parse JSON from Gemini response
    try:
        # If Gemini returns code blocks with triple backticks, strip them
        if response_text.startswith("```json"):
            response_text = response_text[7:-3].strip()

        feedback_data = json.loads(response_text)
    except json.JSONDecodeError as e:
        print("❌ Failed to parse JSON response from Gemini:", e)
        return None

    return feedback_data


def display_feedback(feedback_data, event_name):
    """
    Displays feedback insights in a readable format.

    Parameters:
    - feedback_data (dict): JSON data containing event feedback insights.
    - event_name (str): Name of the event analyzed.
    """

    if not feedback_data:
        print("❌ No feedback data to display.")
        return

    print(f"\n📊 Feedback Summary for Event: {event_name}\n")

    print(f"✅ Positive Feedback Percentage: {feedback_data['positive_feedback_percentage']}%")
    print(f"❌ Negative Feedback Percentage: {feedback_data['negative_feedback_percentage']}%")
    print(f"📝 Total Feedback Considered: {feedback_data['total_feedback_count']} entries")

    print("\n🔹 Category-wise Feedback (%):")
    for category, percentage in feedback_data['categories'].items():
        print(f"   - {category}: {percentage}%")

    print("\n📈 Sentiment Trends Over the Years:")
    for trend in feedback_data['yearly_sentiment_trends']:
        year = trend['year']
        pos = trend['positive']
        neg = trend['negative']
        print(f"   - {year}: Positive={pos}, Negative={neg}")


# === USAGE ===
if __name__ == "__main__":
    # Example Event Name (You can change this!)
    event_name = "Global Music Festival 2024"

    # Fetch feedback insights from Gemini
    feedback_data = fetch_event_feedback(event_name)

    # Display the insights
    display_feedback(feedback_data, event_name)
# Out:
# === RAW RESPONSE ===
#
# ```json
# {
#   "positive_feedback_percentage": 78,
#   "negative_feedback_percentage": 22,
#   "total_feedback_count": 3250,
#   "categories": {
#     "Event Organization": 82,
#     "Content Quality": 88,
#     "Venue & Facilities": 75,
#     "Staff & Service": 72,
#     "Value for Money": 79
#   },
#   "yearly_sentiment_trends": [
#     {"year": 2020, "positive": 200, "negative": 150},
#     {"year": 2021, "positive": 350, "negative": 120},
#     {"year": 2022, "positive": 450, "negative": 100},
#     {"year": 2023, "positive": 550, "negative": 80},
#     {"year": 2024, "positive": 1950, "negative": 500}
#   ]
# }
# ```
#
# ...
#
#
# 📊 Feedback Summary for Event: Global Music Festival 2024
#
# ✅ Positive Feedback Percentage: 78%
# ❌ Negative Feedback Percentage: 22%
# 📝 Total Feedback Considered: 3250 entries
#
# 🔹 Category-wise Feedback (%):
#    - Event Organization: 82%
#    - Content Quality: 88%
#    - Venue & Facilities: 75%
#    - Staff & Service: 72%
# ...

# %%
import google.generativeai as genai
import json
import matplotlib.pyplot as plt

# Configure Gemini Pro
genai.configure(api_key="AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE")  # Replace with your Gemini API Key

# Initialize Gemini Pro Model
model = genai.GenerativeModel("gemini-1.5-pro")


def fetch_event_feedback(event_name):
    """
    Fetches feedback insights for a given event using Gemini LLM.

    Parameters:
    - event_name (str): Name of the event to analyze.

    Returns:
    - dict: Structured feedback insights including positive/negative percentages,
            category breakdowns, and yearly sentiment trends.
    """

    # Detailed prompt sent to Gemini LLM
    prompt = f"""
You are an expert data analyst working for an event management company. You have full access to detailed feedback data collected over the years for the event "{event_name}".

Your job is to:
1. Analyze and summarize the feedback data.
2. Present the insights in a structured JSON format.
3. Make sure the data is consistent and realistic.

Here is what you need to include in the response:

1. **positive_feedback_percentage**: The percentage of all feedback that is classified as positive. Keep it realistic, between 50% and 100%.

2. **negative_feedback_percentage**: The percentage of all feedback that is classified as negative. This should add up with positive feedback to 100%.

3. **total_feedback_count**: A realistic total number of feedback entries considered. Assume the event is popular, so return a number between 500 and 10,000.

4. **categories**: Break down the feedback into the following categories, each with a percentage (out of 100%). Make sure the percentages reflect a well-balanced distribution:
   - Event Organization
   - Content Quality
   - Venue & Facilities
   - Staff & Service
   - Value for Money

5. **yearly_sentiment_trends**: Provide a list of objects, each representing a year. For each year, show:
   - year (last 5 years: from 2020 to 2024)
   - positive (number of positive feedback entries for that year)
   - negative (number of negative feedback entries for that year)
   Ensure that positive feedback generally increases over the years as the event improves, and negative feedback decreases.

### FORMAT:
Return the full response strictly in JSON format like this:

{{
  "positive_feedback_percentage": 85,
  "negative_feedback_percentage": 15,
  "total_feedback_count": 2500,
  "categories": {{
    "Event Organization": 80,
    "Content Quality": 85,
    "Venue & Facilities": 75,
    "Staff & Service": 78,
    "Value for Money": 82
  }},
  "yearly_sentiment_trends": [
    {{"year": 2020, "positive": 300, "negative": 100}},
    {{"year": 2021, "positive": 400, "negative": 90}},
    {{"year": 2022, "positive": 500, "negative": 80}},
    {{"year": 2023, "positive": 600, "negative": 70}},
    {{"year": 2024, "positive": 700, "negative": 50}}
  ]
}}

### Rules:
- Do not include explanations.
- Do not add extra text. Only return the JSON object.
- Ensure the numbers are consistent. Positive + Negative feedback per year should make sense.
"""

    # Generate content from Gemini
    response = model.generate_content(prompt)

    # Get the response text
    response_text = response.text.strip()

    # Optional: Print raw response for debugging
    print("\n=== RAW RESPONSE ===\n")
    print(response_text)
    print("\n====================\n")

    # Parse JSON from Gemini response
    try:
        # Strip code block tags if present
        if response_text.startswith("```json"):
            response_text = response_text[7:-3].strip()

        feedback_data = json.loads(response_text)
    except json.JSONDecodeError as e:
        print("❌ Failed to parse JSON response from Gemini:", e)
        return None

    return feedback_data


def display_feedback(feedback_data, event_name):
    """
    Displays feedback insights in a readable format and draws a sentiment trend graph.

    Parameters:
    - feedback_data (dict): JSON data containing event feedback insights.
    - event_name (str): Name of the event analyzed.
    """

    if not feedback_data:
        print("❌ No feedback data to display.")
        return

    print(f"\n📊 Feedback Summary for Event: {event_name}\n")

    print(f"✅ Positive Feedback Percentage: {feedback_data['positive_feedback_percentage']}%")
    print(f"❌ Negative Feedback Percentage: {feedback_data['negative_feedback_percentage']}%")
    print(f"📝 Total Feedback Considered: {feedback_data['total_feedback_count']} entries")

    print("\n🔹 Category-wise Feedback (%):")
    for category, percentage in feedback_data['categories'].items():
        print(f"   - {category}: {percentage}%")

    print("\n📈 Sentiment Trends Over the Years:")
    years = []
    positives = []
    negatives = []

    for trend in feedback_data['yearly_sentiment_trends']:
        year = trend['year']
        pos = trend['positive']
        neg = trend['negative']
        years.append(year)
        positives.append(pos)
        negatives.append(neg)

        print(f"   - {year}: Positive={pos}, Negative={neg}")

    # Plotting the sentiment trend line graph
    draw_sentiment_trend_graph(years, positives, negatives, event_name)


def draw_sentiment_trend_graph(years, positives, negatives, event_name):
    """
    Plots the sentiment trend graph over the years.

    Parameters:
    - years (list): List of years.
    - positives (list): Positive feedback counts.
    - negatives (list): Negative feedback counts.
    - event_name (str): Name of the event.
    """

    plt.figure(figsize=(10, 6))
    plt.plot(years, positives, marker='o', color='green', label='Positive Feedback')
    plt.plot(years, negatives, marker='o', color='red', label='Negative Feedback')

    plt.title(f"Sentiment Trend for {event_name} (Last 5 Years)", fontsize=14)
    plt.xlabel("Year", fontsize=12)
    plt.ylabel("Number of Feedback Entries", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    plt.show()


# === USAGE ===
if __name__ == "__main__":
    print("🔎 Enter the event name to analyze feedback:")
    event_name = input("Event Name: ")

    # Fetch feedback insights from Gemini
    feedback_data = fetch_event_feedback(event_name)

    # Display the insights and plot the graph
    display_feedback(feedback_data, event_name)
# Out:
# 🔎 Enter the event name to analyze feedback:
# Event Name: Ranveer Allahabdia Podcast
# WARNING:tornado.access:404 POST /v1beta/models/gemini-2.0-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 2553.97ms
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-22-6f9e9c62f61b> in <cell line: 0>()
#     178
#     179     # Fetch feedback insights from Gemini
# --> 180     feedback_data = fetch_event_feedback(event_name)
#     181
#     182     # Display the insights and plot the graph
#
# <ipython-input-22-6f9e9c62f61b> in fetch_event_feedback(event_name)
#      82
#      83     # Generate content from Gemini
# ---> 84     response = model.generate_content(prompt)
#      85
#      86     # Get the response text
#
# ...

# %%
import google.generativeai as genai
import matplotlib.pyplot as plt

# Initialize Gemini Pro Model (Replace with your API key)
genai.configure(api_key="AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE")

model = genai.GenerativeModel("gemini-1.5-pro")

# Function to generate feedback analysis using Gemini
def analyze_event_feedback(event_name):
    prompt = f"""
    You are an expert data analyst working for an event management company.
    You have full access to detailed feedback data collected over the years for events by "{event_name}", a famous stand-up comedian known for performing at college fests, online YouTube streams, and large ticketed live shows.

    The feedback data has been collected from:
    - Ticket booking platforms (BookMyShow, Insider)
    - Social media comments (YouTube, Twitter)
    - Post-event surveys (Google Forms)

    Your job is to:
    1. Analyze and summarize this feedback data.
    2. Present insights that reflect:
       - A growing fanbase for young, college-going audiences.
       - Occasional criticism about venue facilities but highly positive reviews for content quality and humor.
       - Gradual improvement in event organization over the years.

    Return the data in structured JSON format as follows:
    1. positive_feedback_percentage: (Be realistic. Comedy shows often have 80-95% positivity)
    2. negative_feedback_percentage: Remaining percent
    3. total_feedback_count: Between 1000 and 5000 per year.
    4. categories: Break down into these categories with reasonable %:
       - Event Organization
       - Content Quality
       - Venue & Facilities
       - Staff & Service
       - Value for Money
    5. yearly_sentiment_trends:
       - Years: 2020 to 2024
       - Each year should reflect his growth as a comedian: positive feedback increases, negative decreases.

    ### FORMAT:
    {{
      "positive_feedback_percentage": 92,
      "negative_feedback_percentage": 8,
      "total_feedback_count": 4000,
      "categories": {{
        "Event Organization": 85,
        "Content Quality": 95,
        "Venue & Facilities": 75,
        "Staff & Service": 80,
        "Value for Money": 90
      }},
      "yearly_sentiment_trends": [
        {{"year": 2020, "positive": 800, "negative": 200}},
        {{"year": 2021, "positive": 1000, "negative": 150}},
        {{"year": 2022, "positive": 1100, "negative": 120}},
        {{"year": 2023, "positive": 1200, "negative": 80}},
        {{"year": 2024, "positive": 1300, "negative": 50}}
      ]
    }}

    Rules:
    - Do NOT include explanations.
    - Do NOT add extra text. Only the JSON object.
    """

    # Generate content from Gemini
    response = model.generate_content(prompt)

    # Print raw Gemini response (JSON text)
    print("\n🎯 Gemini Response (JSON):\n")
    print(response.text)

    return response.text

# Function to plot the sentiment trend graph
def plot_sentiment_trends(yearly_data, event_name):
    years = [entry['year'] for entry in yearly_data]
    positive_feedback = [entry['positive'] for entry in yearly_data]
    negative_feedback = [entry['negative'] for entry in yearly_data]

    plt.figure(figsize=(10, 6))
    plt.plot(years, positive_feedback, marker='o', linestyle='-', color='green', label='Positive Feedback')
    plt.plot(years, negative_feedback, marker='o', linestyle='-', color='red', label='Negative Feedback')

    plt.title(f"Sentiment Trends Over the Years for {event_name}")
    plt.xlabel("Year")
    plt.ylabel("Feedback Count")
    plt.legend()
    plt.grid(True)
    plt.show()

# Main function to run everything
def main():
    # Get user input
    event_name = input("Enter the event/artist name: ")

    # Call Gemini to analyze feedback
    response_text = analyze_event_feedback(event_name)

    # Convert Gemini response JSON (as text) to Python dictionary safely
    import json
    try:
        feedback_data = json.loads(response_text)
    except json.JSONDecodeError as e:
        print("\n❌ Error parsing Gemini JSON response!")
        print(e)
        return

    # Display feedback summary
    print("\n✅ Event Feedback Analysis Summary:\n")
    print(f"Event: {event_name}")
    print(f"Positive Feedback: {feedback_data['positive_feedback_percentage']}%")
    print(f"Negative Feedback: {feedback_data['negative_feedback_percentage']}%")
    print(f"Total Feedback Considered: {feedback_data['total_feedback_count']}")

    print("\n📊 Feedback Categories Breakdown:")
    for category, percentage in feedback_data['categories'].items():
        print(f"- {category}: {percentage}%")

    # Plot the sentiment trend graph
    plot_sentiment_trends(feedback_data['yearly_sentiment_trends'], event_name)

# Run the program
if __name__ == "__main__":
    main()
# Out:
# Enter the event/artist name: Samay Raina
#
# 🎯 Gemini Response (JSON):
#
# ```json
# {
#   "positive_feedback_percentage": 92,
#   "negative_feedback_percentage": 8,
#   "total_feedback_count": 4200,
#   "categories": {
#     "Event Organization": 88,
#     "Content Quality": 96,
#     "Venue & Facilities": 78,
#     "Staff & Service": 82,
#     "Value for Money": 92
#   },
#   "yearly_sentiment_trends": [
#     {"year": 2020, "positive": 800, "negative": 200},
#     {"year": 2021, "positive": 1050, "negative": 150},
#     {"year": 2022, "positive": 1150, "negative": 100},
#     {"year": 2023, "positive": 1250, "negative": 70},
#     {"year": 2024, "positive": 1350, "negative": 50}
#   ]
# }
# ```
#
#
# ❌ Error parsing Gemini JSON response!
# Expecting value: line 1 column 1 (char 0)

# %%
import google.generativeai as genai
import matplotlib.pyplot as plt
import json
import re

# Configure your Gemini API key here
genai.configure(api_key="AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE")

def analyze_event_feedback(event_name):
    """
    Calls Gemini API to analyze feedback for a given event/artist.
    Returns the raw response text.
    """
    model = genai.GenerativeModel("gemini-1.5-pro")

    prompt = f"""
    You are an expert event analyst. Assume you have access to comprehensive feedback data for the event or artist "{event_name}".

    ✅ Provide the following structured JSON response:

    {{
      "positive_feedback_percentage": (Positive feedback percentage as a number),
      "negative_feedback_percentage": (Negative feedback percentage as a number),
      "total_feedback_count": (Total number of feedback entries as a number),
      "categories": {{
        "Event Organization": (percentage as a number),
        "Content Quality": (percentage as a number),
        "Venue & Facilities": (percentage as a number),
        "Staff & Service": (percentage as a number),
        "Value for Money": (percentage as a number)
      }},
      "yearly_sentiment_trends": [
        {{
          "year": (year as number),
          "positive": (number of positive feedback entries),
          "negative": (number of negative feedback entries)
        }},
        ...
      ]
    }}

    🎯 Ensure the JSON starts with {{ and ends with }}.
    🎯 Do not include explanations, markdown, or additional text.

    Provide accurate and realistic values based on typical feedback trends for events like "{event_name}".
    """

    response = model.generate_content(prompt)
    return response.text.strip()

def clean_json_response(response_text):
    """
    Extracts the JSON content from Gemini's response text.
    """
    # Find the JSON block inside the response
    json_match = re.search(r'\{.*\}', response_text, re.DOTALL)
    if json_match:
        clean_json = json_match.group(0)
        return clean_json
    else:
        raise ValueError("❌ No valid JSON found in Gemini response!")

def plot_sentiment_trends(yearly_trends, event_name):
    """
    Plots a line graph for yearly sentiment trends.
    """
    years = [trend["year"] for trend in yearly_trends]
    positive = [trend["positive"] for trend in yearly_trends]
    negative = [trend["negative"] for trend in yearly_trends]

    plt.figure(figsize=(10, 6))
    plt.plot(years, positive, marker='o', color='green', label='Positive Feedback')
    plt.plot(years, negative, marker='o', color='red', label='Negative Feedback')

    plt.title(f"Sentiment Trends for '{event_name}' Over the Years")
    plt.xlabel("Year")
    plt.ylabel("Feedback Count")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("🎤 Event/Artist Feedback Analyzer\n")
    event_name = input("Enter the event or artist name: ").strip()

    print("\n⏳ Analyzing feedback using Gemini... Please wait...\n")

    try:
        # Get Gemini response
        response_text = analyze_event_feedback(event_name)

        # Debug print: full raw Gemini response
        print("\n📝 Raw Gemini Response:\n")
        print(response_text)

        # Clean and parse JSON
        clean_json = clean_json_response(response_text)

        # Debug print: cleaned JSON string
        print("\n🧹 Cleaned JSON Extracted:\n")
        print(clean_json)

        # Load JSON as Python dict
        feedback_data = json.loads(clean_json)

        # Display the results
        print("\n✅ Event Feedback Analysis Summary:\n")
        print(f"🎤 Event/Artist: {event_name}")
        print(f"👍 Positive Feedback: {feedback_data['positive_feedback_percentage']}%")
        print(f"👎 Negative Feedback: {feedback_data['negative_feedback_percentage']}%")
        print(f"📈 Total Feedback Considered: {feedback_data['total_feedback_count']}")

        print("\n📊 Feedback Categories Breakdown:")
        for category, percentage in feedback_data['categories'].items():
            print(f"- {category}: {percentage}%")

        # Plot the sentiment trends
        plot_sentiment_trends(feedback_data['yearly_sentiment_trends'], event_name)

    except Exception as e:
        print("\n❌ An error occurred while analyzing feedback!")
        print(f"Details: {e}")

if __name__ == "__main__":
    main()
# Out:
# 🎤 Event/Artist Feedback Analyzer
#
# Enter the event or artist name: India's Got Latent
#
# ⏳ Analyzing feedback using Gemini... Please wait...
#
#
# 📝 Raw Gemini Response:
#
# ```json
# {
#   "positive_feedback_percentage": 78.5,
#   "negative_feedback_percentage": 21.5,
#   "total_feedback_count": 1250,
#   "categories": {
#     "Event Organization": 85,
#     "Content Quality": 92,
#     "Venue & Facilities": 70,
#     "Staff & Service": 75,
#     "Value for Money": 80
#   },
#   "yearly_sentiment_trends": [
#     {
#       "year": 2020,
#       "positive": 150,
#       "negative": 50
#     },
#     {
#       "year": 2021,
#       "positive": 280,
#       "negative": 70
#     },
#     {
#       "year": 2022,
#       "positive": 400,
#       "negative": 100
#     },
#     {
#       "year": 2023,
#       "positive": 300,
#       "negative": 80
#     }
#   ]
# }
# ```
#
# 🧹 Cleaned JSON Extracted:
#
# {
#   "positive_feedback_percentage": 78.5,
# ...

# %%
import google.generativeai as genai
import matplotlib.pyplot as plt
import json
import re

# Configure your Gemini API key here
genai.configure(api_key="AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE")

def check_event_existence(event_name):
    """
    Checks if the event or artist exists using Gemini.
    """
    model = genai.GenerativeModel("gemini-1.5-pro")

    prompt = f"""
    Verify if there is an event or artist named "{event_name}" in the entertainment industry, including music, stand-up comedy, talent shows, etc.

    🎯 Respond ONLY with one word:
    - "Yes" if it exists.
    - "No" if it does not exist.

    Do not provide any explanations.
    """

    response = model.generate_content(prompt)
    answer = response.text.strip().lower()

    return answer == "yes"

def analyze_event_feedback(event_name):
    """
    Calls Gemini API to analyze feedback for a given event/artist.
    Returns the raw response text.
    """
    model = genai.GenerativeModel("gemini-1.5-pro")

    prompt = f"""
    You are an expert event analyst. Assume you have access to comprehensive feedback data for the event or artist "{event_name}".

    ✅ Provide the following structured JSON response:

    {{
      "positive_feedback_percentage": (Positive feedback percentage as a number),
      "negative_feedback_percentage": (Negative feedback percentage as a number),
      "total_feedback_count": (Total number of feedback entries as a number),
      "categories": {{
        "Event Organization": (percentage as a number),
        "Content Quality": (percentage as a number),
        "Venue & Facilities": (percentage as a number),
        "Staff & Service": (percentage as a number),
        "Value for Money": (percentage as a number)
      }},
      "yearly_sentiment_trends": [
        {{
          "year": (year as number),
          "positive": (number of positive feedback entries),
          "negative": (number of negative feedback entries)
        }},
        ...
      ]
    }}

    🎯 Ensure the JSON starts with {{ and ends with }}.
    🎯 Do not include explanations, markdown, or additional text.

    Provide accurate and realistic values based on actual feedback trends for events like "{event_name}".
    """

    response = model.generate_content(prompt)
    return response.text.strip()

def clean_json_response(response_text):
    """
    Extracts the JSON content from Gemini's response text.
    """
    # Find the JSON block inside the response
    json_match = re.search(r'\{.*\}', response_text, re.DOTALL)
    if json_match:
        clean_json = json_match.group(0)
        return clean_json
    else:
        raise ValueError("❌ No valid JSON found in Gemini response!")

def plot_sentiment_trends(yearly_trends, event_name):
    """
    Plots a line graph for yearly sentiment trends.
    """
    years = [trend["year"] for trend in yearly_trends]
    positive = [trend["positive"] for trend in yearly_trends]
    negative = [trend["negative"] for trend in yearly_trends]

    plt.figure(figsize=(10, 6))
    plt.plot(years, positive, marker='o', color='green', label='Positive Feedback')
    plt.plot(years, negative, marker='o', color='red', label='Negative Feedback')

    plt.title(f"Sentiment Trends for '{event_name}' Over the Years")
    plt.xlabel("Year")
    plt.ylabel("Feedback Count")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("🎤 Event/Artist Feedback Analyzer\n")
    event_name = input("Enter the event or artist name: ").strip()

    print("\n🔎 Checking if the event or artist exists...\n")

    # STEP 1: Check existence
    if not check_event_existence(event_name):
        print(f"❌ Sorry! The event or artist '{event_name}' doesn't seem to exist.")
        return

    print("✅ Event/Artist found! Proceeding to analyze feedback...\n")
    print("⏳ Analyzing feedback using Gemini... Please wait...\n")

    try:
        # Get Gemini response
        response_text = analyze_event_feedback(event_name)

        # Debug print: full raw Gemini response
        print("\n📝 Raw Gemini Response:\n")
        print(response_text)

        # Clean and parse JSON
        clean_json = clean_json_response(response_text)

        # Debug print: cleaned JSON string
        print("\n🧹 Cleaned JSON Extracted:\n")
        print(clean_json)

        # Load JSON as Python dict
        feedback_data = json.loads(clean_json)

        # Display the results
        print("\n✅ Event Feedback Analysis Summary:\n")
        print(f"🎤 Event/Artist: {event_name}")
        print(f"👍 Positive Feedback: {feedback_data['positive_feedback_percentage']}%")
        print(f"👎 Negative Feedback: {feedback_data['negative_feedback_percentage']}%")
        print(f"📈 Total Feedback Considered: {feedback_data['total_feedback_count']}")

        print("\n📊 Feedback Categories Breakdown:")
        for category, percentage in feedback_data['categories'].items():
            print(f"- {category}: {percentage}%")

        # Plot the sentiment trends
        plot_sentiment_trends(feedback_data['yearly_sentiment_trends'], event_name)

    except Exception as e:
        print("\n❌ An error occurred while analyzing feedback!")
        print(f"Details: {e}")

if __name__ == "__main__":
    main()
# Out:
# 🎤 Event/Artist Feedback Analyzer
#
# Enter the event or artist name: IPL Opening Event
#
# 🔎 Checking if the event or artist exists...
#
# ✅ Event/Artist found! Proceeding to analyze feedback...
#
# ⏳ Analyzing feedback using Gemini... Please wait...
#
#
# 📝 Raw Gemini Response:
#
# ```json
# {
#   "positive_feedback_percentage": 78.5,
#   "negative_feedback_percentage": 21.5,
#   "total_feedback_count": 12500,
#   "categories": {
#     "Event Organization": 85.2,
#     "Content Quality": 92.1,
#     "Venue & Facilities": 75.8,
#     "Staff & Service": 68.3,
#     "Value for Money": 62.7
#   },
#   "yearly_sentiment_trends": [
#     {
#       "year": 2018,
#       "positive": 5500,
#       "negative": 1800
#     },
#     {
#       "year": 2019,
#       "positive": 6200,
#       "negative": 1500
#     },
#     {
#       "year": 2020,
#       "positive": 4800,
#       "negative": 1200
#     },
#     {
#       "year": 2021,
#       "positive": 5200,
#       "negative": 1000
#     },
# ...

# %%
from flask import Flask, request, jsonify
import google.generativeai as genai
import matplotlib.pyplot as plt
import json
import re

# Flask app initialization
app = Flask(__name__)

# Configure Gemini API key
genai.configure(api_key="AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE")

def check_event_existence(event_name):
    """
    Checks if the event or artist exists using Gemini.
    """
    model = genai.GenerativeModel("gemini-1.5-pro")

    prompt = f"""
    Verify if there is an event or artist named "{event_name}" in the entertainment industry, including music, stand-up comedy, talent shows, etc.

    🎯 Respond ONLY with one word:
    - "Yes" if it exists.
    - "No" if it does not exist.

    Do not provide any explanations.
    """

    response = model.generate_content(prompt)
    answer = response.text.strip().lower()

    return answer == "yes"

def analyze_event_feedback(event_name):
    """
    Calls Gemini API to analyze feedback for a given event/artist.
    Returns the raw response text.
    """
    model = genai.GenerativeModel("gemini-1.5-pro")

    prompt = f"""
    You are an expert event analyst. Assume you have access to comprehensive feedback data for the event or artist "{event_name}".

    ✅ Provide the following structured JSON response:

    {{
      "positive_feedback_percentage": (Positive feedback percentage as a number),
      "negative_feedback_percentage": (Negative feedback percentage as a number),
      "total_feedback_count": (Total number of feedback entries as a number),
      "categories": {{
        "Event Organization": (percentage as a number),
        "Content Quality": (percentage as a number),
        "Venue & Facilities": (percentage as a number),
        "Staff & Service": (percentage as a number),
        "Value for Money": (percentage as a number)
      }},
      "yearly_sentiment_trends": [
        {{
          "year": (year as number),
          "positive": (number of positive feedback entries),
          "negative": (number of negative feedback entries)
        }},
        ...
      ]
    }}

    🎯 Ensure the JSON starts with {{ and ends with }}.
    🎯 Do not include explanations, markdown, or additional text.

    Provide accurate and realistic values based on actual feedback trends for events like "{event_name}".
    """

    response = model.generate_content(prompt)
    return response.text.strip()

def clean_json_response(response_text):
    """
    Extracts the JSON content from Gemini's response text.
    """
    # Find the JSON block inside the response
    json_match = re.search(r'\{.*\}', response_text, re.DOTALL)
    if json_match:
        clean_json = json_match.group(0)
        return clean_json
    else:
        raise ValueError("❌ No valid JSON found in Gemini response!")

def plot_sentiment_trends(yearly_trends, event_name):
    """
    Plots a line graph for yearly sentiment trends.
    """
    years = [trend["year"] for trend in yearly_trends]
    positive = [trend["positive"] for trend in yearly_trends]
    negative = [trend["negative"] for trend in yearly_trends]

    plt.figure(figsize=(10, 6))
    plt.plot(years, positive, marker='o', color='green', label='Positive Feedback')
    plt.plot(years, negative, marker='o', color='red', label='Negative Feedback')

    plt.title(f"Sentiment Trends for '{event_name}' Over the Years")
    plt.xlabel("Year")
    plt.ylabel("Feedback Count")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{event_name}_sentiment_trends.png")  # Save the graph as a PNG file
    plt.close()  # Close the plot to prevent display in Flask server

@app.route("/", methods=["GET"])
def home():
    return jsonify({"message": "🎤 Welcome to the Event/Artist Feedback Analyzer API!"})

@app.route("/analyze", methods=["GET"])
def analyze():
    """
    Main API endpoint for event/artist feedback analysis.
    Usage: /analyze?event_name=Coldplay
    """
    event_name = request.args.get("event_name")

    if not event_name:
        return jsonify({"error": "Missing event_name parameter"}), 400

    try:
        # STEP 1: Check existence
        exists = check_event_existence(event_name)

        if not exists:
            return jsonify({"error": f"❌ Event/Artist '{event_name}' doesn't seem to exist!"}), 404

        # STEP 2: Analyze feedback
        response_text = analyze_event_feedback(event_name)

        # STEP 3: Clean JSON and parse it
        clean_json = clean_json_response(response_text)
        feedback_data = json.loads(clean_json)

        # STEP 4: Plot sentiment trends and save the graph
        plot_sentiment_trends(feedback_data['yearly_sentiment_trends'], event_name)

        # Return the results as JSON
        return jsonify({
            "message": f"✅ Feedback analysis for '{event_name}' completed!",
            "event_name": event_name,
            "feedback_summary": feedback_data,
            "sentiment_trend_graph": f"{event_name}_sentiment_trends.png"
        })

    except Exception as e:
        return jsonify({"error": str(e)}), 500

if __name__ == "__main__":
    # Run on host=0.0.0.0 to expose it via ngrok
    app.run(host="0.0.0.0", port=5000, debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat

# %%
# Install dependencies (skip if already installed)
# !pip install flask
# !pip install pyngrok
# !pip install google-generativeai

# Imports
from flask import Flask, request, jsonify
import google.generativeai as genai
import json
import re
from pyngrok import ngrok

# Configure Gemini API Key
genai.configure(api_key="AIzaSyB496cy--F89mqK8va8SPcE87TuKqYO9mE")

# Define your functions (copied from your code)
def check_event_existence(event_name):
    model = genai.GenerativeModel("gemini-1.5-pro")

    prompt = f"""
    Verify if there is an event or artist named "{event_name}" in the entertainment industry, including music, stand-up comedy, talent shows, etc.

    🎯 Respond ONLY with one word:
    - "Yes" if it exists.
    - "No" if it does not exist.

    Do not provide any explanations.
    """

    response = model.generate_content(prompt)
    answer = response.text.strip().lower()

    return answer == "yes"

def analyze_event_feedback(event_name):
    model = genai.GenerativeModel("gemini-1.5-pro")

    prompt = f"""
    You are an expert event analyst. Assume you have access to comprehensive feedback data for the event or artist "{event_name}".

    ✅ Provide the following structured JSON response:

    {{
      "positive_feedback_percentage": (Positive feedback percentage as a number),
      "negative_feedback_percentage": (Negative feedback percentage as a number),
      "total_feedback_count": (Total number of feedback entries as a number),
      "categories": {{
        "Event Organization": (percentage as a number),
        "Content Quality": (percentage as a number),
        "Venue & Facilities": (percentage as a number),
        "Staff & Service": (percentage as a number),
        "Value for Money": (percentage as a number)
      }},
      "yearly_sentiment_trends": [
        {{
          "year": (year as number),
          "positive": (number of positive feedback entries),
          "negative": (number of negative feedback entries)
        }}
      ]
    }}

    🎯 Ensure the JSON starts with {{ and ends with }}.
    🎯 Do not include explanations, markdown, or additional text.

    Provide accurate and realistic values based on actual feedback trends for events like "{event_name}".
    """

    response = model.generate_content(prompt)
    return response.text.strip()

def clean_json_response(response_text):
    json_match = re.search(r'\{.*\}', response_text, re.DOTALL)
    if json_match:
        clean_json = json_match.group(0)
        return clean_json
    else:
        raise ValueError("❌ No valid JSON found in Gemini response!")

# Create Flask App
app = Flask(__name__)

@app.route("/")
def index():
    return "🎤 Welcome to the Event/Artist Feedback Analyzer API!"

@app.route("/analyze", methods=["GET"])
def analyze():
    event_name = request.args.get("event_name", "").strip()

    if not event_name:
        return jsonify({"error": "⚠️ Missing 'event_name' parameter!"}), 400

    if not check_event_existence(event_name):
        return jsonify({"error": f"❌ Event or artist '{event_name}' does not exist!"}), 404

    try:
        response_text = analyze_event_feedback(event_name)
        clean_json = clean_json_response(response_text)
        feedback_data = json.loads(clean_json)

        return jsonify({
            "event_name": event_name,
            "analysis": feedback_data
        })

    except Exception as e:
        return jsonify({"error": f"❌ Error analyzing feedback: {str(e)}"}), 500

# Start ngrok tunnel
ngrok_tunnel = ngrok.connect(5000)  # Forward traffic to Flask's default port (5000)
print("Ngrok Tunnel URL:", ngrok_tunnel.public_url)

# Run the Flask app
app.run()
